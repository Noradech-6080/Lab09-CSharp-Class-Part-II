// %% [markdown]
// # Lab 9 Exercise 1
//
// ## การใช้งาน Modifier

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotbet new conxole --name Lab09_Ex01
// ```

// %% [markdown]
// ถ้ารันคำสั่งไม่ได้ ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Person.name = "_________________";
// >   System.conso1e.writ1ine(Person.GetName());
// >
// >   static class Person
// >   {
// >       public static st__ng? name;
// >       public static stri__ GetName()
// >       {
// >           return $"Hello from {name}";
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotdet build  Lab09_Ex0_
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// Build succeeded.
//
//     0 Warning(s)
//
//     0 Error(s)
//
// Time Elapsed 00:00:12.67

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotxet run --project Lab_9_Ex_1
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// Hello from Noradech

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// จะได้ผลลัพธ์ Hello from Noradech

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Static field และ static method ต่างจาก instance field และ instance method อย่างไร

// %% [markdown]
// static field / static method → เป็นของ คลาส ใช้ร่วมกันทุกออบเจ็กต์ เรียกใช้ผ่านคลาสโดยตรง
//
// instance field / instance method → เป็นของ ออบเจ็กต์ แต่ละออบเจ็กต์มีค่าของตัวเอง ต้องสร้างออบเจ็กต์ก่อนใช้

// %% [markdown]
// 2. เหตุใดเราจึงสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อ class โดยไม่ต้องสร้าง object

// %% [markdown]
// เราสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อคลาส เพราะทั้ง field (name) และ method (GetName()) ถูกประกาศเป็น static ซึ่งเป็นสมาชิกของคลาส ไม่ต้องสร้างออบเจ็กต์ก็สามารถเรียกใช้ได้

// %% [markdown]
// 3. Static class มีข้อจำกัดอะไรบ้าง

// %% [markdown]
// ข้อจำกัดของ static class ใน C#:
//
// 1. ไม่สามารถสร้าง instance (ออบเจ็กต์) ได้
//
// 2. ไม่รองรับ inheritance (สืบทอดคลาส)
//
// 3. สมาชิกทั้งหมดต้องเป็น static
//
// 4. ไม่สามารถใช้ interface ได้

// %% [markdown]
// 4. เราไม่สามารถสร้าง instance ของ static class ได้เพราะอะไร

// %% [markdown]
// เพราะ C# บล็อกการสร้างออบเจ็กต์ของ static class โดยอัตโนมัติ และ static class ถูกออกแบบให้ใช้ผ่านชื่อคลาสโดยตรง ไม่ต้องมีออบเจ็กต์

// %% [markdown]
// 5. ประโยชน์ของการใช้ static class คืออะไร  มีสถานการณ์ใดบ้างที่เราควรใช้ static class

// %% [markdown]
// ประโยชน์ของ static class
//
// 1. ประหยัดหน่วยความจำ (ไม่ต้องสร้างออบเจ็กต์)
//
// 2. ใช้งานง่าย เรียกใช้ผ่านชื่อคลาสโดยตรง
//
// 3. ป้องกันการเปลี่ยนแปลงสถานะของออบเจ็กต์
//
// สถานการณ์ที่ควรใช้ static class
//
// 1. คลาสที่ให้ utility functions เช่น Math
//
// 2. คลาสที่เก็บ ค่าคงที่ (const) หรือ config
//
// 3. คลาสที่ใช้ จัดการข้อมูลระดับโปรแกรม เช่น Logger หรือ Helper
